# %%
# Prepare data: Figure 2 fitness1 vs. fitness2 (mean fitness of all or selected samples)
import pandas as pd
import numpy as np

def load_metric_point_label(csv_path, label, rows=[0,1], metric_col='mean'):
    df = pd.read_csv(csv_path)
    metrics = df[metric_col].values[rows]
    x = metrics[0]
    y = metrics[1]
    
    return x, y, label

DDG_GFP_labels = []
csv_path_label = [['../logs_new/GWG_2_2023_10_03__10_02_12_weight_1.8_0.2/samples_20231003-100212/evaluation_metrics_nested_selection.csv','weight_1.8_0.2'],
                 ['../logs_new/GWG_2_2023_10_03__09_45_59_weight_1.5_0.5/samples_20231003-094559/evaluation_metrics_nested_selection.csv', 'weight_1.5_0.5'],
                 ['../logs_new/GWG_2_2023_09_30__16_13_27/samples_20230930-161327/evaluation_metrics_nested_selection.csv', 'weight_1.0_1.0'],
                 ['../logs_new/GWG_2_2023_10_03__09_46_26_weight_0.5_1.5/samples_20231003-094626/evaluation_metrics_nested_selection.csv', 'weight_0.5_1.5'],
                 ['../logs_new/GWG_2_2023_10_03__10_02_40_weight_0.2_1.8/samples_20231003-100240/evaluation_metrics_nested_selection.csv', 'weight_0.2_1.8'],
                 ['../logs_new/GWG_2_2023_10_01__10_37_47_avg_lambda_6/samples_20231001-103747/evaluation_metrics_nested_selection.csv', 'linear'],
                 ['../logs_new/train_smooth_GFP_2023_09_30__13_34_58/samples_20230930-135740/evaluation_metrics.csv', 'GWG_GFP'],
                 ['../logs_new/train_predictor_stability_0.2_0.4_2023_09_30__10_43_49/samples_20230930-104911/evaluation_metrics.csv', 'GWG_DDG'],
                #  ['../logs_baseline_new/random_sample_GFP_2023_10_01__12_07_24_0.2_0.4/evaluation_metrics_single_task.csv', 'random_GFP'],
                #  ['../logs_baseline_new/random_sample_stability_2023_10_01__12_07_34_0.2_0.4/evaluation_metrics_single_task.csv', 'random_DDG'],
                 ['../logs_baseline_new/adalead_GFP_2023_10_02__16_52_36/evaluation_metrics_single_task.csv', 'adalead_GFP'],
                 ['../logs_new/GWG_2_2023_10_03__11_25_16_weight_0.8_1.2/samples_20231003-112516/evaluation_metrics_nested_selection.csv', 'weight_0.8_1.2'],
                 ['../logs_new/GWG_2_2023_10_03__11_24_40_weight_1.2_0.8/samples_20231003-112440/evaluation_metrics_nested_selection.csv', 'weight_1.2_0.8'],
                 ['../logs_new/GWG_2_2023_10_03__12_02_37_weight_0.9_1.1/samples_20231003-120237/evaluation_metrics_nested_selection.csv', 'weight_0.9_1.1'],
                 ['../logs_new/GWG_2_2023_10_03__12_03_03_weight_1.1_0.9/samples_20231003-120303/evaluation_metrics_nested_selection.csv', 'weight_1.1_0.9'],]
for csv_path, label in csv_path_label:
    DDG_GFP_labels.append(load_metric_point_label(csv_path, label, [0,1], 'mean_fitness'))
DDG, GFP, labels_DDG_GFP = zip(*DDG_GFP_labels)

gb1_ddg_labels = []
csv_path_label = [['../logs_new/train_predictor_gb1_0_0.4_2023_10_05__15_12_17_augment/samples_20231005-163504/evaluation_metrics.csv', 'GWG_GB1'],
                  ['../logs_new/train_predictor_ddg_0_0.4_2023_10_05__15_12_56_agument/samples_20231005-163745/evaluation_metrics.csv', 'GWG_DDG'],
                  ['../logs_new/GWG_2_gb1_ddg_2023_10_05__21_58_09_debug/samples_20231005-215809/evaluation_metrics.csv', 'pareto_la1'],
                  ['../logs_new/GWG_2_gb1_ddg_2023_10_06__10_33_21_lambda5/samples_20231006-103321/evaluation_metrics.csv', 'pareto_la5'],
                  ['../logs_new/GWG_2_gb1_ddg_2023_10_06__10_36_17_lambda0.5/samples_20231006-103617/evaluation_metrics.csv', 'pareto_la0.5'],
                  ['../logs_new/GWG_2_gb1_ddg_2023_10_06__10_40_58_lambda2.0/samples_20231006-104058/evaluation_metrics.csv', 'pareto_la2.0'],
                #   ['../logs_new/GWG_2_gb1_ddg_pref_vec_2023_10_11__11_10_07_pref_index_4/samples_20231011-111007/evaluation_metrics.csv', 'pareto_pref_vec_4'],
                #   ['../logs_new/GWG_2_gb1_ddg_pref_vec_2023_10_11__11_15_06_pref_index_0/samples_20231011-111506/evaluation_metrics.csv', 'pareto_pref_vec_0'],
                #   ['../logs_new/GWG_2_gb1_ddg_pref_vec_2023_10_11__15_42_28_pref_index_1/samples_20231011-154228/evaluation_metrics.csv', 'pareto_pref_vec_1'],
                #   ['../logs_new/GWG_2_gb1_ddg_pref_vec_2023_10_11__15_42_57_pref_index_2/samples_20231011-154257/evaluation_metrics.csv', 'pareto_pref_vec_2'],
                #   ['../logs_new/GWG_2_gb1_ddg_pref_vec_2023_10_11__15_43_11_pref_index_3/samples_20231011-154311/evaluation_metrics.csv', 'pareto_pref_vec_3'],
                #   ['../logs_pref_vec/GWG_2_gb1_ddg_pref_vec_2023_10_12__16_59_27_pref_index_0/samples_20231012-165927/evaluation_metrics.csv', 'pareto_pref_vec_0'],
                #   ['../logs_pref_vec/GWG_2_gb1_ddg_pref_vec_2023_10_12__16_59_42_pref_index_1/samples_20231012-165942/evaluation_metrics.csv', 'pareto_pref_vec_1'],
                #   ['../logs_pref_vec/GWG_2_gb1_ddg_pref_vec_2023_10_12__16_59_48_pref_index_2/samples_20231012-165948/evaluation_metrics.csv', 'pareto_pref_vec_2'],
                #   ['../logs_pref_vec/GWG_2_gb1_ddg_pref_vec_2023_10_12__16_59_55_pref_index_3/samples_20231012-165955/evaluation_metrics.csv', 'pareto_pref_vec_3'],
                #   ['../logs_pref_vec/GWG_2_gb1_ddg_pref_vec_2023_10_12__17_00_02_pref_index_4/samples_20231012-170002/evaluation_metrics.csv', 'pareto_pref_vec_4'],
                #   ['../logs_linear/GWG_2_gb1_ddg_linear_2023_10_13__09_44_38_weight_0.1/samples_20231013-094438/evaluation_metrics.csv', 'pareto_linear_0.1'],
                #   ['../logs_linear/GWG_2_gb1_ddg_linear_2023_10_13__09_51_41_weight_0.3/samples_20231013-095141/evaluation_metrics.csv', 'pareto_linear_0.3'],
                #   ['../logs_linear/GWG_2_gb1_ddg_linear_2023_10_13__09_52_41_weight_0.7/samples_20231013-095241/evaluation_metrics.csv', 'pareto_linear_0.7'],
                #   ['../logs_linear/GWG_2_gb1_ddg_linear_2023_10_13__09_53_13_weight_0.9/samples_20231013-095313/evaluation_metrics.csv', 'pareto_linear_0.9'],
                #   ['../logs_linear/GWG_2_gb1_ddg_linear_2023_10_13__09_53_37_weight_1.0/samples_20231013-095337/evaluation_metrics.csv', 'pareto_linear_1.0'],
                #   ['../logs_linear/GWG_2_gb1_ddg_linear_2023_10_13__09_54_06_weight_0.0/samples_20231013-095406/evaluation_metrics.csv', 'pareto_linear_0.0'],
                  ['../logs_baseline_new/random_gb1_2023_10_10__10_16_02_no_select/evaluation_metrics.csv', 'random_gb1'],
                  ['../logs_baseline_new/random_ddg_2023_10_10__10_17_45_no_select/evaluation_metrics.csv', 'random_ddg'],
                  ['../logs_baseline_new/adalead_gb1_2023_10_10__09_39_11/evaluation_metrics.csv', 'adalead_gb1'],
                  ['../logs_baseline_new/adalead_ddg_2023_10_10__09_39_59/evaluation_metrics.csv', 'adalead_ddg']]
for csv_path, label in csv_path_label:
    gb1_ddg_labels.append(load_metric_point_label(csv_path, label, [0,1], 'mean'))
gb1, ddg, labels_gb1_ddg = zip(*gb1_ddg_labels)

E3_E2_labels = []
csv_path_label = [
                  ['../logs_new/GWG_2_E3_E2_2023_10_07__22_51_34_debug/samples_20231007-225134/evaluation_metrics.csv', 'lambda_1.0'],
                  ['../logs_new/GWG_2_E3_E2_2023_10_07__22_57_59_lambda2.0/samples_20231007-225759/evaluation_metrics.csv', 'lambda_2.0'],
                  ['../logs_new/GWG_2_E3_E2_2023_10_07__23_00_12_lambda3.0/samples_20231007-230012/evaluation_metrics.csv', 'lambda_3.0'],
                  ['../logs_new/GWG_2_E3_E2_2023_10_07__23_03_58_lambda5.0/samples_20231007-230358/evaluation_metrics.csv', 'lambda_5.0'],
                  ['../logs_new/GWG_2_E3_E2_2023_10_07__23_05_51_lambda10.0/samples_20231007-230551/evaluation_metrics.csv', 'lambda_10.0'],
                  ['../logs_new/GWG_2_E3_E2_2023_10_07__23_07_33_lambda0.5/samples_20231007-230733/evaluation_metrics.csv', 'lambda_0.5'],
                  ['../logs_new/GWG_2_E3_E2_2023_10_07__23_10_57_lambda0.1/samples_20231007-231057/evaluation_metrics.csv', 'lambda_0.1'],
                  ['../logs_new/GWG_2_E3_E2_2023_10_07__23_43_23_lambda0.0/samples_20231007-234323/evaluation_metrics.csv', 'lambda_0.0'],
                  ['../logs_new/GWG_2_E3_E2_pref_vec_2023_10_11__09_40_54_pref_index_0/samples_20231011-094054/evaluation_metrics.csv', 'pareto_pref_vec_0'],
                #   ['../logs_new/GWG_2_E3_E2_pref_vec_2023_10_11__10_03_09_pref_index_4/samples_20231011-100309/evaluation_metrics.csv', 'pareto_pref_vec_4'],
                #   ['../logs_new/GWG_2_E3_E2_pref_vec_2023_10_11__10_23_25_pref_index_3/samples_20231011-102325/evaluation_metrics.csv', 'pareto_pref_vec_3'],
                #   ['../logs_new/GWG_2_E3_E2_pref_vec_2023_10_11__15_51_12_pref_index_1/samples_20231011-155112/evaluation_metrics.csv', 'pareto_pref_vec_1'],
                #   ['../logs_new/GWG_2_E3_E2_pref_vec_2023_10_11__15_51_30_pref_index_2/samples_20231011-155130/evaluation_metrics.csv', 'pareto_pref_vec_2'],
                #   ['../logs_pref_vec/GWG_2_E3_E2_pref_vec_2023_10_12__16_24_22_pref_index_0/samples_20231012-162422/evaluation_metrics.csv', 'pareto_pref_vec_0'],
                #   ['../logs_pref_vec/GWG_2_E3_E2_pref_vec_2023_10_12__16_11_25_pref_index_2/samples_20231012-161125/evaluation_metrics.csv', 'pareto_pref_vec_2'],
                #   ['../logs_pref_vec/GWG_2_E3_E2_pref_vec_2023_10_12__16_44_48_pref_index_3/samples_20231012-164448/evaluation_metrics.csv', 'pareto_pref_vec_3'],
                #   ['../logs_pref_vec/GWG_2_E3_E2_pref_vec_2023_10_12__16_44_55_pref_index_4/samples_20231012-164455/evaluation_metrics.csv', 'pareto_pref_vec_4'],
                #   ['../logs_linear/GWG_2_E3_E2_linear_2023_10_13__09_51_50_weight_0.0/samples_20231013-095150/evaluation_metrics.csv', 'pareto_linear_0.0'],
                #   ['../logs_linear/GWG_2_E3_E2_linear_2023_10_13__09_53_14_weight_0.1/samples_20231013-095314/evaluation_metrics.csv', 'pareto_linear_0.1'],
                #   ['../logs_linear/GWG_2_E3_E2_linear_2023_10_13__09_54_58_weight_0.3/samples_20231013-095458/evaluation_metrics.csv', 'pareto_linear_0.3'],
                #   ['../logs_linear/GWG_2_E3_E2_linear_2023_10_13__09_57_12_weight_0.5/samples_20231013-095712/evaluation_metrics.csv', 'pareto_linear_0.5'],
                #   ['../logs_linear/GWG_2_E3_E2_linear_2023_10_13__09_59_10_weight_0.7/samples_20231013-095910/evaluation_metrics.csv', 'pareto_linear_0.7'],
                #   ['../logs_linear/GWG_2_E3_E2_linear_2023_10_13__10_00_43_weight_0.9/samples_20231013-100043/evaluation_metrics.csv', 'pareto_linear_0.9'],
                #   ['../logs_linear/GWG_2_E3_E2_linear_2023_10_13__10_01_53_weight_1.0/samples_20231013-100153/evaluation_metrics.csv', 'pareto_linear_1.0'],
                  ['../logs_new/GWG_2_E3_E2_2023_10_07__23_15_24_average/samples_20231007-231524/evaluation_metrics.csv', 'linear'],
                  ['../logs_new/train_predictor_E2_0.1_0.4_2023_10_07__22_43_47_augment/samples_20231007-224624/evaluation_metrics.csv', 'GWG_E2'],
                  ['../logs_new/train_predictor_E3_0.1_0.4_2023_10_07__22_43_44_augment/samples_20231007-224622/evaluation_metrics.csv', 'GWG_E3'],
                  ['../logs_baseline_new/random_E3_2023_10_10__10_19_14_no_select/evaluation_metrics.csv', 'random_E3'],
                  ['../logs_baseline_new/random_E2_2023_10_10__10_18_58_no_select/evaluation_metrics.csv', 'random_E2'],]
for csv_path, label in csv_path_label:
    E3_E2_labels.append(load_metric_point_label(csv_path, label, [0,1], 'mean'))
E3, E2, labels_E3_E2 = zip(*E3_E2_labels)

# %%
# Figure 2 fitness1 vs. fitness2 (mean fitness of all or selected samples)
# transform to a function
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy.interpolate import make_interp_spline
from scipy.optimize import curve_fit

def inverse_func(x, a, b):
    return a / x + b

fig, axs = plt.subplots(nrows=1, ncols=3, figsize=(15, 5))

colors = plt.cm.jet(np.linspace(0, 1, 6))
# axs[0].scatter(GFP, DDG, s=50, c='red')
# Create a scatter plot for each point
pareto_legend_added = False
pareto_GFP, pareto_DDG = [], []
pareto_count = 0
for i, (x, y, label) in enumerate(zip(GFP, DDG, labels_DDG_GFP)):
    if 'weight' in label:
        axs[0].scatter(x, y, color='red', marker='^', label='pareto' if not pareto_legend_added else None)  # Triangle marker for labels containing 'weight'
        pareto_legend_added = True
        pareto_GFP.append(x)
        pareto_DDG.append(y)
        pareto_count += 1
    else:
        axs[0].scatter(x, y, color=colors[i-pareto_count], label=label)
axs[0].set_xlabel('GFP fitness', fontsize=16)
axs[0].set_ylabel('DDG', fontsize=16)
axs[0].set_title('DDG vs. GFP fitness', fontsize=16)
# Display the legend below the plot
axs[0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=3)
# fit the pareto front curve
# Create a smoother x range
sorted_indices = np.argsort(pareto_GFP)
pareto_GFP = np.array(pareto_GFP)[sorted_indices]
pareto_DDG = np.array(pareto_DDG)[sorted_indices]
# coefficients = np.polyfit(pareto_GFP, pareto_DDG, 2)
# polynomial = np.poly1d(coefficients)
# xnew = np.linspace(min(pareto_GFP), max(pareto_GFP), 300)
# ynew = polynomial(xnew)
# axs[0].plot(xnew, ynew, color='red', linestyle='--', linewidth=2)


pareto_legend_added = False
pareto_count = 0
for i, (x, y, label) in enumerate(zip(gb1, ddg, labels_gb1_ddg)):
    if 'pareto' in label:
        axs[1].scatter(x, y, color='red', marker='^', label='pareto' if not pareto_legend_added else None)  # Triangle marker for labels containing 'weight'
        pareto_legend_added = True
        pareto_count += 1
    else:
        axs[1].scatter(x, y, color=colors[i - pareto_count], label=label)
axs[1].set_xlabel('GB1 fitness', fontsize=16)
axs[1].set_ylabel('DDG', fontsize=16)
axs[1].set_title('DDG vs. GB1 fitness', fontsize=16)
# Display the legend below the plot
axs[1].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=3)


pareto_legend_added = False
pareto_E3, pareto_E2 = [], []
# print(len(E3), len(E2), len(labels_E3_E2))
# input()
pareto_count = 0
for i, (x, y, label) in enumerate(zip(E3, E2, labels_E3_E2)):
    if 'lambda' in label or 'pareto' in label:
        axs[2].scatter(x, y, color='red', marker='^', label='pareto' if not pareto_legend_added else None)  # Triangle marker for labels containing 'weight'
        pareto_legend_added = True
        pareto_E3.append(x)
        pareto_E2.append(y)
        pareto_count += 1
    else:
        axs[2].scatter(x, y, color=colors[i - pareto_count], label=label)
axs[2].set_xlabel('E3 fitness', fontsize=16)
axs[2].set_ylabel('E2 fitness', fontsize=16)
axs[2].set_title('E2 fitness vs. E3 fitness', fontsize=16)
# Display the legend below the plot
axs[2].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), fancybox=True, shadow=False, ncol=3)

sorted_indices = np.argsort(pareto_E3)
pareto_E3 = np.array(pareto_E3)[sorted_indices]
pareto_E2 = np.array(pareto_E2)[sorted_indices]
params, covariance = curve_fit(inverse_func, pareto_E3, pareto_E2)
xnew = np.linspace(min(pareto_E3), max(pareto_E3), 300)
ynew = inverse_func(xnew, *params)
# axs[2].plot(xnew, ynew, color='red', linestyle='--', linewidth=2)

plt.tight_layout()
plt.savefig('../results/fitness1_vs_fitness2.png', dpi=300)
plt.savefig('../results/fitness1_vs_fitness2.svg', dpi=300)
plt.show()
# fix experiment settings
